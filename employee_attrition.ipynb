# %%
import pandas as pd
import os
os.environ['KAGGLE_USERNAME']='dinesh223344'
os.environ['KAGGLE_KEY']='KGAT_4f293546a7b4700c41008b912382b767'

# %%
# !kaggle datasets download -d 'stealthtechnologies/employee-attrition-dataset'
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/stealthtechnologies/employee-attrition-dataset
# License(s): apache-2.0
# ...
# 100% 1.72M/1.72M [00:00<00:00, 80.7MB/s]

# %%
# !unzip /content/employee-attrition-dataset.zip
# Out:
# Archive:  /content/employee-attrition-dataset.zip
#   inflating: test.csv
#   inflating: train.csv

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/train.csv")

# %%
df.head()
# Out:
#    Employee ID  Age  Gender  Years at Company    Job Role  Monthly Income  \
# 0         8410   31    Male                19   Education            5390
# 1        64756   59  Female                 4       Media            5534
# 2        30257   24  Female                10  Healthcare            8159
# 3        65791   36  Female                 7   Education            3989
# 4        65026   56    Male                41   Education            4821
#
#   Work-Life Balance Job Satisfaction Performance Rating  Number of Promotions  \
# 0         Excellent           Medium            Average                     2
# 1              Poor             High                Low                     3
# 2              Good             High                Low                     0
# 3              Good             High               High                     1
# 4              Fair        Very High            Average                     0
#
# ...

# %%
df.tail()
# Out:
#        Employee ID  Age  Gender  Years at Company    Job Role  Monthly Income  \
# 59593        37195   50  Female                12   Education            4414
# 59594         6266   18    Male                 4  Healthcare            8040
# 59595        54887   22  Female                14  Technology            7944
# 59596          861   23    Male                 8   Education            2931
# 59597        15796   56    Male                19  Technology            6660
#
#       Work-Life Balance Job Satisfaction Performance Rating  \
# 59593              Fair             High            Average
# 59594              Fair             High               High
# 59595              Fair             High               High
# 59596              Fair        Very High            Average
# 59597              Good             High            Average
#
#        Number of Promotions  ... Number of Dependents  Job Level Company Size  \
# ...

# %%
df.describe()
# Out:
#         Employee ID           Age  Years at Company  Monthly Income  \
# count  59598.000000  59598.000000      59598.000000    59598.000000
# mean   37227.118729     38.565875         15.753901     7302.397983
# std    21519.150028     12.079673         11.245981     2151.457423
# min        1.000000     18.000000          1.000000     1316.000000
# 25%    18580.250000     28.000000          7.000000     5658.000000
# 50%    37209.500000     39.000000         13.000000     7354.000000
# 75%    55876.750000     49.000000         23.000000     8880.000000
# max    74498.000000     59.000000         51.000000    16149.000000
#
#        Number of Promotions  Distance from Home  Number of Dependents  \
# count          59598.000000        59598.000000          59598.000000
# mean               0.832578           50.007651              1.648075
# std                0.994991           28.466459              1.555689
# min                0.000000            1.000000              0.000000
# ...

# %%
df.isnull().sum()
# Out:
# Employee ID                 0
# Age                         0
# Gender                      0
# Years at Company            0
# Job Role                    0
# Monthly Income              0
# Work-Life Balance           0
# Job Satisfaction            0
# Performance Rating          0
# Number of Promotions        0
# Overtime                    0
# Distance from Home          0
# Education Level             0
# Marital Status              0
# Number of Dependents        0
# Job Level                   0
# Company Size                0
# Company Tenure              0
# Remote Work                 0
# Leadership Opportunities    0
# Innovation Opportunities    0
# Company Reputation          0
# Employee Recognition        0
# Attrition                   0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df["Age_group"]=pd.cut(
    df["Age"],
    bins=[0,19,30,60,100],labels=["teen","adult","old","too old"])

# %%
le = LabelEncoder()
categorical_cols = ['Age_group','Gender','Job Role','Work-Life Balance','Job Satisfaction','Performance Rating','Overtime','Education Level','Marital Status','Job Level','Company Size','Remote Work','Leadership Opportunities','Innovation Opportunities','Company Reputation','Employee Recognition','Attrition']

for col in categorical_cols:
    df[col] = le.fit_transform(df[col])
    print(f"Column '{col}' encoded successfully.")

display(df.head())
# Out:
# Column 'Age_group' encoded successfully.
# Column 'Gender' encoded successfully.
# Column 'Job Role' encoded successfully.
# Column 'Work-Life Balance' encoded successfully.
# Column 'Job Satisfaction' encoded successfully.
# Column 'Performance Rating' encoded successfully.
# Column 'Overtime' encoded successfully.
# Column 'Education Level' encoded successfully.
# Column 'Marital Status' encoded successfully.
# Column 'Job Level' encoded successfully.
# Column 'Company Size' encoded successfully.
# Column 'Remote Work' encoded successfully.
# Column 'Leadership Opportunities' encoded successfully.
# Column 'Innovation Opportunities' encoded successfully.
# Column 'Company Reputation' encoded successfully.
# Column 'Employee Recognition' encoded successfully.
# Column 'Attrition' encoded successfully.
#    Employee ID  Age  Gender  Years at Company  Job Role  Monthly Income  \
# 0         8410   31       1                19         0            5390
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59598 entries, 0 to 59597
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Employee ID               59598 non-null  int64
#  1   Age                       59598 non-null  int64
#  2   Gender                    59598 non-null  int64
#  3   Years at Company          59598 non-null  int64
#  4   Job Role                  59598 non-null  int64
#  5   Monthly Income            59598 non-null  int64
#  6   Work-Life Balance         59598 non-null  int64
#  7   Job Satisfaction          59598 non-null  int64
#  8   Performance Rating        59598 non-null  int64
#  9   Number of Promotions      59598 non-null  int64
#  10  Overtime                  59598 non-null  int64
#  11  Distance from Home        59598 non-null  int64
#  12  Education Level           59598 non-null  int64
#  13  Marital Status            59598 non-null  int64
# ...

# %%
for col in df:
  Q1=df[col].quantile(0.25)
  Q3=df[col].quantile(0.75)

  IQR = Q3-Q1
  lower=Q1 - 1.5 *IQR
  upper=Q3 + 1.5 *IQR

  outliers =df[(df[col]<lower) | (df[col] > upper)]

  print(f"{col} : {len(outliers)} outliers")
# Out:
# Employee ID : 0 outliers
# Age : 0 outliers
# Gender : 0 outliers
# Years at Company : 273 outliers
# Job Role : 0 outliers
# Monthly Income : 50 outliers
# Work-Life Balance : 0 outliers
# Job Satisfaction : 0 outliers
# Performance Rating : 2950 outliers
# Number of Promotions : 0 outliers
# Overtime : 0 outliers
# Distance from Home : 0 outliers
# Education Level : 0 outliers
# Marital Status : 0 outliers
# Number of Dependents : 0 outliers
# Job Level : 0 outliers
# Company Size : 0 outliers
# Company Tenure : 0 outliers
# Remote Work : 11359 outliers
# Leadership Opportunities : 2918 outliers
# Innovation Opportunities : 9703 outliers
# Company Reputation : 0 outliers
# Employee Recognition : 0 outliers
# Attrition : 0 outliers
# Age_group : 0 outliers

# %%
df.drop("Employee ID",axis=1,inplace=True)

# %%
x=df.drop(['Attrition'],axis=1)
y=df['Attrition']

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
x = pd.get_dummies(x,drop_first=True)
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.4,random_state=82)
X_train=scaler.fit_transform(x_train)
X_test=scaler.transform(x_test)
x.head()
# Out:
#    Age  Gender  Years at Company  Job Role  Monthly Income  Work-Life Balance  \
# 0   31       1                19         0            5390                  0
# 1   59       0                 4         3            5534                  3
# 2   24       0                10         2            8159                  2
# 3   36       0                 7         0            3989                  2
# 4   56       1                41         0            4821                  1
#
#    Job Satisfaction  Performance Rating  Number of Promotions  Overtime  ...  \
# 0                 2                   0                     2         0  ...
# 1                 0                   3                     3         0  ...
# 2                 0                   3                     0         0  ...
# 3                 0                   2                     1         0  ...
# 4                 3                   0                     0         1  ...
#
# ...

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# %%
model=DecisionTreeClassifier()
model.fit(X_train,y_train)
y_pred=model.predict(X_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.6604026845637584

# %%
model.score(X_test,y_test)
# Out:
# 0.6604026845637584

# %%
from sklearn.ensemble import RandomForestClassifier
model1=RandomForestClassifier()
model1.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.6604026845637584

# %%
model1.score(X_test,y_test)
# Out:
# 0.7416107382550335

# %%
from sklearn.ensemble import GradientBoostingClassifier
mode=GradientBoostingClassifier(learning_rate=0.1,max_depth=3,n_estimators=100,random_state=42)
mode.fit(X_train,y_train)
# Out:
# GradientBoostingClassifier(random_state=42)

# %%
y_pred=mode.predict(X_test)
accuracy=accuracy_score(y_test,y_pred)
print("Accuracy:",accuracy)
# Out:
# Accuracy: 0.7550335570469798

# %%
from sklearn.ensemble import AdaBoostClassifier
model1=AdaBoostClassifier(random_state=42,learning_rate=0.1,n_estimators=100)
model1.fit(X_train,y_train)
# Out:
# AdaBoostClassifier(learning_rate=0.1, n_estimators=100, random_state=42)

# %%
y_pred=model1.predict(X_test)
accuracy=accuracy_score(y_test,y_pred)
print("Accuracy:",accuracy)
# Out:
# Accuracy: 0.7071728187919463

# %%
from xgboost import XGBClassifier
model2=XGBClassifier(random_state=42,learning_rate=0.1,n_estimators=100)
model2.fit(X_train,y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=True, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=100,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
y_pred=model2.predict(X_test)
accuracy=accuracy_score(y_test,y_pred)
print("Accuracy:",accuracy)
# Out:
# Accuracy: 0.7567114093959731

# %%
from lightgbm import LGBMClassifier
model3=LGBMClassifier(n_estimators=100,random_state=42)
model3.fit(X_train,y_train)
# Out:
# [LightGBM] [Info] Number of positive: 18729, number of negative: 17029
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.006767 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 658
# [LightGBM] [Info] Number of data points in the train set: 35758, number of used features: 23
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.523771 -> initscore=0.095155
# [LightGBM] [Info] Start training from score 0.095155
# LGBMClassifier(random_state=42)

# %%
y_pred=model3.predict(X_test)
accuracy=accuracy_score(y_test,y_pred)
print("Accuracy:",accuracy)
# Out:
# Accuracy: 0.7560822147651006
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(

# %%
# !pip install catboost
from catboost import CatBoostClassifier
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.1/97.1 MB 6.8 MB/s eta 0:00:00
# ...

# %%
model4=CatBoostClassifier(n_estimators=100,max_depth=3,random_state=42)
model4.fit(X_train,y_train)
# Out:
# Learning rate set to 0.391944
# 0:	learn: 0.6151654	total: 104ms	remaining: 10.3s
# 1:	learn: 0.5854544	total: 135ms	remaining: 6.6s
# 2:	learn: 0.5701912	total: 148ms	remaining: 4.78s
# 3:	learn: 0.5574969	total: 161ms	remaining: 3.87s
# 4:	learn: 0.5449092	total: 195ms	remaining: 3.7s
# 5:	learn: 0.5348008	total: 234ms	remaining: 3.66s
# 6:	learn: 0.5277078	total: 271ms	remaining: 3.6s
# 7:	learn: 0.5227862	total: 316ms	remaining: 3.63s
# 8:	learn: 0.5173141	total: 345ms	remaining: 3.48s
# 9:	learn: 0.5132414	total: 357ms	remaining: 3.21s
# 10:	learn: 0.5080747	total: 368ms	remaining: 2.98s
# 11:	learn: 0.5045238	total: 379ms	remaining: 2.78s
# 12:	learn: 0.5017636	total: 391ms	remaining: 2.62s
# 13:	learn: 0.4993006	total: 403ms	remaining: 2.47s
# 14:	learn: 0.4965961	total: 417ms	remaining: 2.36s
# 15:	learn: 0.4943256	total: 427ms	remaining: 2.24s
# 16:	learn: 0.4923589	total: 438ms	remaining: 2.14s
# 17:	learn: 0.4901940	total: 449ms	remaining: 2.05s
# ...

# %%
y_pred=model4.predict(X_test)
accuracy=accuracy_score(y_test,y_pred)
print("Accuracy:",accuracy)
# Out:
# Accuracy: 0.7598154362416107

# %%
from sklearn.model_selection import GridSearchCV
from catboost import CatBoostClassifier


param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [3, 5, 7],
    'learning_rate': [0.01, 0.05, 0.1]
}

cat_model = CatBoostClassifier(random_state=42, verbose=0)
grid_search = GridSearchCV(estimator=cat_model, param_grid=param_grid,
                           cv=3, n_jobs=-1, verbose=2, scoring='accuracy')


grid_search.fit(X_train, y_train)


print(f"Best parameters found: {grid_search.best_params_}")
print(f"Best accuracy found: {grid_search.best_score_}")


best_cat_model = grid_search.best_estimator_
y_pred_tuned = best_cat_model.predict(X_test)
accuracy_tuned = accuracy_score(y_test, y_pred_tuned)
print(f"Test accuracy with best CatBoost model: {accuracy_tuned}")
# Out:
# Fitting 3 folds for each of 27 candidates, totalling 81 fits
# Best parameters found: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 200}
# Best accuracy found: 0.7576486713166221
# Test accuracy with best CatBoost model: 0.7586409395973155

# %%
import pickle

filename = 'best_catboost_model.pkl'
pickle.dump(best_cat_model, open(filename, 'wb'))

print(f"Best CatBoost model saved to {filename}")
# Out:
# Best CatBoost model saved to best_catboost_model.pkl
